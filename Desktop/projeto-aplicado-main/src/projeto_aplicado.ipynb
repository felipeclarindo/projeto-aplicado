# %% [markdown]
# # Projeto Aplicado
#
# Análise Exploratoria de Dados
#
# ## Objetivo
#
# Identificar insights sobre as condições habítais no estados de São Paulo (Brasil)

# %% [markdown]
# ## Baixando bibliotecas

# %%
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: matplotlib in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 2)) (3.10.1)
# Requirement already satisfied: seaborn in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 3)) (0.13.2)
# Requirement already satisfied: ipykernel in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 4)) (6.29.5)
# Requirement already satisfied: numpy>=1.26.0 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from pandas->-r ../requirements.txt (line 1)) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from pandas->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from pandas->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from pandas->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 2)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 2)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 2)) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 2)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 2)) (3.2.3)
# Requirement already satisfied: appnope in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (1.8.13)
# Requirement already satisfied: ipython>=7.23.1 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (9.0.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: psutil in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (26.3.0)
# Requirement already satisfied: tornado>=6.1 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (5.14.3)
# Requirement already satisfied: decorator in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (2.19.1)
# Requirement already satisfied: stack_data in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r ../requirements.txt (line 4)) (4.3.7)
# Requirement already satisfied: six>=1.5 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/felipeclarindo/Desktop/projeto-aplicado-main/.venv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importando bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from utils.utils import check_folder, correct_zeros

# %% [markdown]
# ## Checando existencia das pastas

# %%
check_folder('data')
check_folder('data/raw')
check_folder('data/processed')

# %% [markdown]
# ## Carregando Dataset

# %%
df = pd.read_csv('./data/raw/housing_conditions_sao_paulo.csv', encoding='latin1', sep=';')

df
# Out:
#                 cd_setor    cd_dist       nm_dist  area_km2   cd_mun  \
# 0       350010505000001P  350010505    Adamantina  0,123823  3500105
# 1       350010505000002P  350010505    Adamantina  0,202614  3500105
# 2       350010505000003P  350010505    Adamantina  0,235051  3500105
# 3       350010505000004P  350010505    Adamantina  0,288466  3500105
# 4       350010505000005P  350010505    Adamantina  0,213725  3500105
# ...                  ...        ...           ...       ...      ...
# 102413  355730305000032P  355730305  Estiva Gerbi  0,123545  3557303
# 102414  355730305000033P  355730305  Estiva Gerbi  0,149444  3557303
# 102415  355730305000034P  355730305  Estiva Gerbi  0,080984  3557303
# 102416  355730305000035P  355730305  Estiva Gerbi  0,145167  3557303
# 102417  355730305000036P  355730305  Estiva Gerbi  0,087543  3557303
#
#               nm_mun  v0001  v0002  v0003  v0004        v0005        v0006  \
# 0         Adamantina    288    199    199      0  2,086956522  16,66666667
# 1         Adamantina    674    339    339      0  2,407142857  1,428571429
# 2         Adamantina    380    269    268      1  1,914141414   4,04040404
# 3         Adamantina    570    290    288      2  2,398305085  1,271186441
# 4         Adamantina    612    313    312      1  2,220588235  4,044117647
# ...              ...    ...    ...    ...    ...          ...          ...
# 102413  Estiva Gerbi    715    248    248      0  3,029661017            0
# 102414  Estiva Gerbi    715    244    244      0  3,235294118   4,07239819
# 102415  Estiva Gerbi    405    133    133      0  3,188976378  5,511811024
# 102416  Estiva Gerbi    525    193    193      0  2,932960894  3,351955307
# 102417  Estiva Gerbi    451    182    181      1  2,777777778  4,320987654
#
#         v0007         lat        long
# 0         138  -21,688438  -51,074292
# 1         280  -21,685514  -51,076817
# 2         198  -21,685055  -51,072516
# 3         236  -21,690612  -51,069465
# 4         272  -21,692962  -51,072040
# ...       ...         ...         ...
# 102413    236  -22,267680  -46,947312
# 102414    221  -22,272328  -46,943025
# 102415    127  -22,274732  -46,941732
# 102416    179  -22,275331  -46,956579
# 102417    162  -22,277883  -46,954311
#
# [102418 rows x 15 columns]

# %% [markdown]
# ## Mudando nome das colunas

# %%
df.rename(columns={
    'cd_setor': 'sector_id',
    'cd_dist': 'district_id',
    'nm_dist': 'district_name',
    'area_km2': 'sector_area_km2',
    'cd_mun': 'municipality_id',
    'nm_mun': 'municipality_name',
    'v0001': 'total_sector_population',
    'v0002': 'private_households_population',
    'v0003': 'permanent_households_population',
    'v0004': 'improvised_households_population',
    'v0005': 'population_density_km2',
    'v0006': 'household_trash_collection_percentage',
    'v0007': 'total_sector_households',
    'lat': 'sector_latitude',
    'long': 'sector_longitude'
}, inplace=True)

check_folder('data/processed')
df.to_csv('./data/processed/housing_conditions_sao_paulo_columns_names_changed.csv', index=False)

df
# Out:
#                sector_id  district_id district_name sector_area_km2  \
# 0       350010505000001P    350010505    Adamantina        0,123823
# 1       350010505000002P    350010505    Adamantina        0,202614
# 2       350010505000003P    350010505    Adamantina        0,235051
# 3       350010505000004P    350010505    Adamantina        0,288466
# 4       350010505000005P    350010505    Adamantina        0,213725
# ...                  ...          ...           ...             ...
# 102413  355730305000032P    355730305  Estiva Gerbi        0,123545
# 102414  355730305000033P    355730305  Estiva Gerbi        0,149444
# 102415  355730305000034P    355730305  Estiva Gerbi        0,080984
# 102416  355730305000035P    355730305  Estiva Gerbi        0,145167
# 102417  355730305000036P    355730305  Estiva Gerbi        0,087543
#
#         municipality_id municipality_name  total_sector_population  \
# 0               3500105        Adamantina                      288
# 1               3500105        Adamantina                      674
# 2               3500105        Adamantina                      380
# 3               3500105        Adamantina                      570
# 4               3500105        Adamantina                      612
# ...                 ...               ...                      ...
# 102413          3557303      Estiva Gerbi                      715
# 102414          3557303      Estiva Gerbi                      715
# 102415          3557303      Estiva Gerbi                      405
# 102416          3557303      Estiva Gerbi                      525
# 102417          3557303      Estiva Gerbi                      451
#
#         private_households_population  permanent_households_population  \
# 0                                 199                              199
# 1                                 339                              339
# 2                                 269                              268
# 3                                 290                              288
# 4                                 313                              312
# ...                               ...                              ...
# 102413                            248                              248
# 102414                            244                              244
# 102415                            133                              133
# 102416                            193                              193
# 102417                            182                              181
#
#         improvised_households_population population_density_km2  \
# 0                                      0            2,086956522
# 1                                      0            2,407142857
# 2                                      1            1,914141414
# 3                                      2            2,398305085
# 4                                      1            2,220588235
# ...                                  ...                    ...
# 102413                                 0            3,029661017
# 102414                                 0            3,235294118
# 102415                                 0            3,188976378
# 102416                                 0            2,932960894
# 102417                                 1            2,777777778
#
#        household_trash_collection_percentage  total_sector_households  \
# 0                                16,66666667                      138
# 1                                1,428571429                      280
# 2                                 4,04040404                      198
# 3                                1,271186441                      236
# 4                                4,044117647                      272
# ...                                      ...                      ...
# 102413                                     0                      236
# 102414                            4,07239819                      221
# 102415                           5,511811024                      127
# 102416                           3,351955307                      179
# 102417                           4,320987654                      162
#
#        sector_latitude sector_longitude
# 0           -21,688438       -51,074292
# 1           -21,685514       -51,076817
# 2           -21,685055       -51,072516
# 3           -21,690612       -51,069465
# 4           -21,692962       -51,072040
# ...                ...              ...
# 102413      -22,267680       -46,947312
# 102414      -22,272328       -46,943025
# 102415      -22,274732       -46,941732
# 102416      -22,275331       -46,956579
# 102417      -22,277883       -46,954311
#
# [102418 rows x 15 columns]

# %% [markdown]
# ## Informações do dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102418 entries, 0 to 102417
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   sector_id                              102418 non-null  object
#  1   district_id                            102418 non-null  int64
#  2   district_name                          102418 non-null  object
#  3   sector_area_km2                        102418 non-null  object
#  4   municipality_id                        102418 non-null  int64
#  5   municipality_name                      102418 non-null  object
#  6   total_sector_population                102418 non-null  int64
#  7   private_households_population          102418 non-null  int64
#  8   permanent_households_population        102418 non-null  int64
#  9   improvised_households_population       102418 non-null  int64
#  10  population_density_km2                 102418 non-null  object
#  11  household_trash_collection_percentage  102418 non-null  object
#  12  total_sector_households                102418 non-null  int64
#  13  sector_latitude                        102418 non-null  object
#  14  sector_longitude                       102418 non-null  object
# dtypes: int64(7), object(8)
# memory usage: 11.7+ MB

# %% [markdown]
# ## Tratamento de dados

# %%
df = df.dropna()
df = df.drop_duplicates()

df['population_density_km2'] = pd.to_numeric(df['population_density_km2'], errors='coerce').dropna()
df['municipality_id'] = pd.to_numeric(df['municipality_id'], errors='coerce')
df['district_name'] = df['district_name'].astype(str)
df['municipality_name'] = df['municipality_name'].astype(str)

check_folder('data/processed')
df.to_csv('./data/processed/housing_conditions_sao_paulo_cleaned.csv', index=False)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102418 entries, 0 to 102417
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   sector_id                              102418 non-null  object
#  1   district_id                            102418 non-null  int64
#  2   district_name                          102418 non-null  object
#  3   sector_area_km2                        102418 non-null  object
#  4   municipality_id                        102418 non-null  int64
#  5   municipality_name                      102418 non-null  object
#  6   total_sector_population                102418 non-null  int64
#  7   private_households_population          102418 non-null  int64
#  8   permanent_households_population        102418 non-null  int64
#  9   improvised_households_population       102418 non-null  int64
#  10  population_density_km2                 5594 non-null    float64
#  11  household_trash_collection_percentage  102418 non-null  object
#  12  total_sector_households                102418 non-null  int64
#  13  sector_latitude                        102418 non-null  object
#  14  sector_longitude                       102418 non-null  object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 11.7+ MB

# %% [markdown]
# ## Criando coluna com a porcentagem de familia privada na população

# %%
df['percentage_private_households'] = ((df['private_households_population'] / df['total_sector_population']) * 100).round(1)
df['permanent_households_population'] = df['permanent_households_population'].apply(correct_zeros)
df['permanent_households_population'] = df['permanent_households_population'].fillna(0)

df.to_csv('./data/processed/housing_conditions_sao_paulo_percentage_private_households_added.csv', index=False)

df
# Out:
#                sector_id  district_id district_name sector_area_km2  \
# 0       350010505000001P    350010505    Adamantina        0,123823
# 1       350010505000002P    350010505    Adamantina        0,202614
# 2       350010505000003P    350010505    Adamantina        0,235051
# 3       350010505000004P    350010505    Adamantina        0,288466
# 4       350010505000005P    350010505    Adamantina        0,213725
# ...                  ...          ...           ...             ...
# 102413  355730305000032P    355730305  Estiva Gerbi        0,123545
# 102414  355730305000033P    355730305  Estiva Gerbi        0,149444
# 102415  355730305000034P    355730305  Estiva Gerbi        0,080984
# 102416  355730305000035P    355730305  Estiva Gerbi        0,145167
# 102417  355730305000036P    355730305  Estiva Gerbi        0,087543
#
#         municipality_id municipality_name  total_sector_population  \
# 0               3500105        Adamantina                      288
# 1               3500105        Adamantina                      674
# 2               3500105        Adamantina                      380
# 3               3500105        Adamantina                      570
# 4               3500105        Adamantina                      612
# ...                 ...               ...                      ...
# 102413          3557303      Estiva Gerbi                      715
# 102414          3557303      Estiva Gerbi                      715
# 102415          3557303      Estiva Gerbi                      405
# 102416          3557303      Estiva Gerbi                      525
# 102417          3557303      Estiva Gerbi                      451
#
#         private_households_population  permanent_households_population  \
# 0                                 199                              199
# 1                                 339                              339
# 2                                 269                              268
# 3                                 290                              288
# 4                                 313                              312
# ...                               ...                              ...
# 102413                            248                              248
# 102414                            244                              244
# 102415                            133                              133
# 102416                            193                              193
# 102417                            182                              181
#
#         improvised_households_population  population_density_km2  \
# 0                                      0                     NaN
# 1                                      0                     NaN
# 2                                      1                     NaN
# 3                                      2                     NaN
# 4                                      1                     NaN
# ...                                  ...                     ...
# 102413                                 0                     NaN
# 102414                                 0                     NaN
# 102415                                 0                     NaN
# 102416                                 0                     NaN
# 102417                                 1                     NaN
#
#        household_trash_collection_percentage  total_sector_households  \
# 0                                16,66666667                      138
# 1                                1,428571429                      280
# 2                                 4,04040404                      198
# 3                                1,271186441                      236
# 4                                4,044117647                      272
# ...                                      ...                      ...
# 102413                                     0                      236
# 102414                            4,07239819                      221
# 102415                           5,511811024                      127
# 102416                           3,351955307                      179
# 102417                           4,320987654                      162
#
#        sector_latitude sector_longitude  percentage_private_households
# 0           -21,688438       -51,074292                           69.1
# 1           -21,685514       -51,076817                           50.3
# 2           -21,685055       -51,072516                           70.8
# 3           -21,690612       -51,069465                           50.9
# 4           -21,692962       -51,072040                           51.1
# ...                ...              ...                            ...
# 102413      -22,267680       -46,947312                           34.7
# 102414      -22,272328       -46,943025                           34.1
# 102415      -22,274732       -46,941732                           32.8
# 102416      -22,275331       -46,956579                           36.8
# 102417      -22,277883       -46,954311                           40.4
#
# [102418 rows x 16 columns]

# %% [markdown]
# ## Media e Mediana da população e familia por setor

# %%
mean_sector_population = df['total_sector_population'].mean()
median_sector_population = df['total_sector_population'].median()

mean_sector_households = df['total_sector_households'].mean()
median_sector_households = df['total_sector_households'].median()

print(f'Média de familia total por setor: {mean_sector_households:.2f}')
print(f'Mediana de familia total por setor: {median_sector_households:.2f}')

print(f'Média da população total por setor: {mean_sector_population:.2f}')
print(f'Mediana da população total por setor: {median_sector_population:.2f}')
# Out:
# Média de familia total por setor: 158.58
# Mediana de familia total por setor: 159.00
# Média da população total por setor: 433.63
# Mediana da população total por setor: 424.00

# %% [markdown]
# ## Gerando gráficos

# %% [markdown]
# ### Distribuição da População total por setor

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['percentage_private_households'], df['permanent_households_population'], marker='o')
plt.xlabel('Porcentagem de Hóspedes Privados')
plt.ylabel('Frequência')
plt.title('Distribuição da População Total por Setor')
plt.show()

# %% [markdown]
# ### Relação entre Dominicios e População Total por Setor

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['total_sector_households'], df['total_sector_population'], marker='o')
plt.xlabel('Total de Domicílios por Setor')
plt.ylabel('Total de População por Setor')
plt.title('Relação entre Domicílios e População Total por Setor')
plt.show()

# %% [markdown]
# ### Top 10 Municípios com Maior Densidade Populacional

# %%
df_municipality = df.groupby('municipality_name')['population_density_km2'].mean().reset_index()
df_municipality = df_municipality.sort_values(by='population_density_km2', ascending=False)

top_10_municipality = df_municipality.head(10)

plt.figure(figsize=(14, 8))
sns.barplot(x='municipality_name', y='population_density_km2', data=top_10_municipality, palette='viridis')
plt.title('Top 10 Municípios com Maior Densidade Populacional', fontsize=16)
plt.xlabel('Município', fontsize=14)
plt.ylabel('Densidade Populacional Média (habitantes por km²)', fontsize=12)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/my/rrqppt2d2dx7s0kbzd7j2sfw0000gq/T/ipykernel_7501/3619017204.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='municipality_name', y='population_density_km2', data=top_10_municipality, palette='viridis')

# %% [markdown]
# ## Distribuição da densidade populacional por km2

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x=df['population_density_km2'], color='lightcoral')
plt.title('Violinplot da Densidade Populacional por km²')
plt.xlabel('Densidade Populacional (hab/km²)')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ### Distribuição da Densidade Populacional por Faixas de Domicílios no Setor

# %%
df_grouped = df.groupby('total_sector_households')['population_density_km2'].mean().reset_index().drop_duplicates()
df_grouped['household_range'] = pd.cut(df_grouped['total_sector_households'], bins=range(0, df_grouped['total_sector_households'].max(), 100), right=False)

plt.figure(figsize=(10, 6))
sns.barplot(x='population_density_km2', y='household_range', data=df_grouped, palette='viridis')
plt.title('Distribuição da Densidade Populacional por Faixas de Domicílios no Setor', fontsize=16)
plt.xlabel('Densidade Populacional Média (habitantes por km²)', fontsize=14)
plt.ylabel('Faixa de Total de Domicílios no Setor', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
# Out:
# /var/folders/my/rrqppt2d2dx7s0kbzd7j2sfw0000gq/T/ipykernel_7501/4268802212.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='population_density_km2', y='household_range', data=df_grouped, palette='viridis')

# %% [markdown]
# # Análise Exploratória de Dados - Condições Habitacionais em São Paulo (Relatório)
#
# ## Principais Insights
#
# 1.  **Distribuição da População e Famílias:**
#     * Disparidades significativas na distribuição da população total e densidade populacional entre as regiões.
#     * Correlação entre a porcentagem de domicílios privados e a população permanente em domicílios permanentes, necessitando investigação mais profunda.
#     * Variação entre a média e mediana da população e número de domicílios por setor, indicando possíveis outliers.
#
# 2.  **Densidade Populacional:**
#     * Identificação da faixa de densidade populacional mais comum e presença de outliers através de histogramas.
#     * Necessidade de infraestrutura e serviços públicos em setores com alta densidade.
#     * Desafios específicos em setores com baixa densidade.
#
# 3.  **Coleta de Lixo e Domicílios Privados:**
#     * Importância da coleta de lixo e porcentagem de domicílios privados na avaliação da qualidade de vida e condições sanitárias.
#
# 4.  **Dados por Município:**
#     * Identificação de padrões regionais através da agregação de dados por município.
#     * Compreensão dos maiores desafios regionais ao analisar população total, número de domicílios, densidade populacional, coleta de lixo e domicílios privados.
